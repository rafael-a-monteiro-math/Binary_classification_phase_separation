# %% [markdown]
# # PSBC - grid search notebook
#
# Goal: perform PSBC model evaluation on a grid in the folder "../Grids", on the main folder.
#
# How: it creates a folder "vary_Nt", where different values of Nt in {1,2,4} are evaluated.
#
# Input:
# * Neumann: bool (True or False), denotes the type of Boundary condition.
# * subordinate: bool (True or False, default is True) to describe the type of model
# * parallel: bool (True or False, default is False), in case the model is parallel
# * with_PCA: bool (True or False, default is False), in case a different basis matrix is used
#
#
# Initially, we need to allow google drive to access the folders with files.

# %%
Colab = False #True

# %%
if Colab:
    from google.colab import drive
    drive.mount ('/content/drive')

# %% [markdown]
# Then we import the libraries we will need.

# %%
#import  matplotlib.pyplot as plt
import scipy.sparse as sc
import itertools as it
import pandas as pd
import numpy as np
import warnings
import shutil 
import copy
import glob
import sys
import os
import time
import tensorflow as tf
from tensorflow import keras
try: ## In order to open and save dictionaries, "dt": self.dt, "kind" : "Viscosity"
    import cPickle as pickle
except ImportError:  # python 3.x
    import pickle

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import multiprocess as mp
warnings.filterwarnings(action = "ignore", message = "internal issue")

# %% [markdown]
# At this moment we are in the folder

# %%
folder_now = os.getcwd ()
print (folder_now)
# Out:
# /home/rafa-monteiro/Desktop/2021/Research/Phase_separation_tensorflow/PSBC

# %% [markdown]
# We then move to the folder we need, and import the folder with all the libraries we will use.

# %%
if Colab: 
    os.chdir ("/content/drive/MyDrive/PSBC/")

sys.path.insert (0, "MOTHER_PSBC/")
folder_now = os.getcwd ()
print (folder_now)
# Out:
# /home/rafa-monteiro/Desktop/2021/Research/Phase_separation_tensorflow/Parameter_search

# %% [markdown]
# which are

# %%
from tfversion_binary_phase_separation import *
from tf_PSBC_extra_libs_for_training_and_grid_search import *

# %% [markdown]
# Now we access the appropriate folder

# %%
print ("Folder options are 'Neumann', 'Periodic', 'PCA_196', 'Classifier_196'")

which_folder = "Neumann"

try: 
    os.mkdir (which_folder)
except:
    pass

os.chdir (which_folder)
print (os.getcwd ())
# Out:
# Folder options are 'Neumann', 'Periodic', 'PCA_196', 'Classifier_196'
# /home/rafa-monteiro/Desktop/2021/Research/Phase_separation_tensorflow/Parameter_search/Neumann

# %% [markdown]
# ## Setting the parameters.

# %%
if which_folder in ['Neumann', 'Periodic']:
    # Recall that grid search happens for eps = 0, hence both models 
    # are the same, because no diffusion is in place
    Neumann = which_folder == 'Neumann'
    subordinate = True
    with_PCA = False     ### Funny thing:if you do "bool("False")" you get True 
    parallel = False
    cpu = 4  ## In case of parallel processing
    Nx = 784
elif which_folder == 'Neumann_non_subordinate':
    Neumann = True
    subordinate = False
    with_PCA = False     ### Funny thing:if you do "bool("False")" you get True 
    parallel = False
    cpu = 4  ## In case of parallel processing
    Nx = 784
elif which_folder == 'PCA_196':
    Neumann = True
    subordinate = True
    with_PCA = True     ### Funny thing:if you do "bool("False")" you get True 
    parallel = False
    cpu = 4  ## In case of parallel processing
    Nx = 784
elif which_folder == 'Classifier_196':
    Neumann = True
    Nt = 2
    save_history = True
    Nx = 784
    subordinate = True
    ###--------- INPUT -------------------------------------------------------------
    ### READ VARIABLES AND RETRIEVE TRAINING DATA (BOTH VARIABLES COMBINED)
    with_PCA = False
    cpu = int (4)
    parallel = False

grid_type = "grid_search" #"training"#
    
print ("The model will perform \n", grid_type,
       "\nwith the following parameters:\n* Neumann is",
       Neumann, "\n* with_PCA is", with_PCA,
       "\n* subordinate is", subordinate,"\n* parallel is", parallel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7068bcd838bb> in <module>
# ----> 1 if which_folder in ['Neumann', 'Periodic']:
#       2     # Recall that grid search happens for eps = 0, hence both models
#       3     # are the same, because no diffusion is in place
#       4     Neumann = which_folder == 'Neumann'
#       5     subordinate = True
#
# NameError: name 'which_folder' is not defined

# %% [markdown]
# ## Computations

# %%
if which_folder == 'PCA_196':
    nt_range  = [2]
    digits_range = [0,1]  ## Will be ignored
    pairs_of_digits = [(4,9), (3, 5)]    
elif which_folder == 'Classifier_196':
    nt_range  = [2]
    digits_range = np.arange (0,45)
else:
    nt_range = [1,2,4]
    digits_range = [0]
# Out:
# {'EPOCHS': 10,
#  'Neumann': True,
#  'Nt': 4,
#  'cv': 5,
#  'patience': 10,
#  'train_dt_P': True,
#  'train_dt_U': True}

# %% [markdown]
# > **Remark** : if you are running this model in Colab you'd better use TPUs or GPUs to speed up grid search. In this case it is also convenient to break the processing in cases, doing one folder Nt at a time, or chopping the digits_range in pieces, in case of classifiers.
# In general, each batch evaluation runs pretty fast, and setting EPOCHS larger than 10 was a bit of an overkill. You can change that if you want.

# %%
print ("\nGrid Search - ", which_folder)
for index in digits_range:
    for Nt in nt_range:
        try: 
            os.mkdir (str (Nt))
        except: 
            pass
        
        os.chdir (str (Nt))

        if which_folder in ['PCA_196', 'Classifier_196']:
            parameters_model = create_grid_for_search (Nt, "classifier")
        else:
            parameters_model = create_grid_for_search (Nt, "vary_Nt")

        ### RETRIEVE PARAMETERS
        filename = "grid_search_" + str (Neumann)+ "_" + str (Nt) + ".p"
        with open ("../../Grids/" + filename, 'rb') as pickled_dic:
            grid_range  = pickle.load (pickled_dic)

        with open ("../../Grids/digits_index.p", 'rb') as pickled_dic:
            grid_indexes  = pickle.load (pickled_dic)

        print (parameters_model)
        cv = grid_range ["cv"]

        ############################################
        print ("Asserting Nt")
        assert (grid_range["Nt"] == Nt)
        print ("Asserting Neumann")
        assert (grid_range["Neumann"] == Neumann)
        print (grid_range)
        ############################################

        EPOCHS = grid_range ["EPOCHS"]
        patience = grid_range ["patience"]
        Nt = grid_range ["Nt"]
        train_dt_U = grid_range ["train_dt_U"]
        train_dt_P = grid_range ["train_dt_P"]

        ###-----------------------------------------------------------------------------
        ### READ VARIABLES AND RETRIEVE TRAINING DATA (BOTH VARIABLES COMBINED)
        if with_PCA:
            variable_0, variable_1 = pairs_of_digits [index]
        else:
            variable_0, variable_1 = grid_indexes [index] 

        print ("\n* Number of cross valications :", cv)
        print ("Variables given:\n\tvariable_0 :",\
              variable_0,"\n\tvariable_1 :", variable_1)
        print ("\n* Parallel is", parallel,\
               ". (If parallel is True, then use ", cpu," cores.)")
        print ("\n* Nx :", Nx, ", Neumann :", Neumann,\
               ", Epochs : ", EPOCHS, ", Patience : ", patience)
        print ("\n* Nt :",  Nt, ", train_dt_U :",\
               train_dt_U, ", train_dt_P :", train_dt_P)
        print ("\n* with_PCA :", with_PCA)

        ###-----------------------------------------------------------------------------
    
        ## retrieve non-shuffled data
        S = select_split_pickle (level= 2)
        X_all, Y_all, _ = S.select_variables_from_pickle (variable_0, variable_1)

        ###  RETRIEVE TRAIN-TEST INDEXES and 
        file_name = "../../Pickled_datasets/generate_k_fold_" +\
        str (variable_0) + "_" + str (variable_1) + ".p"

        with open (file_name, 'rb') as pickled_dic:
            generate_k_fold = pickle.load (pickled_dic)

        results = []      
        #####################################################################
        ### BEGIN PARALLEL PROCESSING
        if parallel:
            print ("\nRUNNING THE MODEL IN PARALLEL")
            a = time.time ()
            pool = mp.Pool(cpu)
            for i in range(cv):
                ### Normalized and centralized (mean zero)
                train_index, test_index,\
                  mean_train_grid, Vstar, var_0_pickled, var_1_pickled =\
                generate_k_fold [str (i)]

                assert (variable_0 == var_0_pickled)
                assert (variable_1 == var_1_pickled)

                ### Split
                X_train_grid, Y_train_grid = X_all[train_index], Y_all[train_index]
                ### Centralization 
                #mean_train_grid = np.mean (X_train_grid, axis = 0)
                X_train_grid = X_train_grid - mean_train_grid
                X_test_grid, Y_test_grid =\
                X_all [test_index] - mean_train_grid, Y_all [test_index]

                ### Now run grid search IN PARALLEL
                print ("\nUsing", cpu, "processors")
                # Step 3: Use loop to parallelize
                args_now = (
                    i, X_train_grid, Y_train_grid, X_test_grid,\
                    Y_test_grid, parameters_model,\
                    Nx, Neumann, EPOCHS , patience, Nt,\
                    train_dt_U, train_dt_P, with_PCA, Vstar
                )
                results.append(
                    pool.apply_async(my_gridSearch_with_index, args = args_now ))
            
            # results is a list of pool.ApplyResult objects
            all_results = [r.get () for r in results]
            pool.close ()
            pool.join ()
            print ("\n It took", time.time () -a, "to run the model in parallel")
        else:
            print ("\nRUNNING THE MODEL IN SERIALLY")
            a = time.time ()
            for i in range(cv):
                ### Normalized and centralized (mean zero)
                train_index, test_index,\
                  mean_train_grid, Vstar, var_0_pickled, var_1_pickled =\
                generate_k_fold [str (i)]

                assert (variable_0 == var_0_pickled)
                assert (variable_1 == var_1_pickled)

                ### Split
                X_train_grid, Y_train_grid = X_all [train_index], Y_all [train_index]
                ### Centralization 
                X_train_grid = X_train_grid - mean_train_grid
                X_test_grid, Y_test_grid = X_all [test_index] - mean_train_grid, Y_all [test_index]

                ### Now run grid search IN PARALLEL
                print ("\nUsing", cpu, "processors")
                results.append (
                    my_gridSearch_with_index (
                        i, X_train_grid, Y_train_grid,\
                        X_test_grid, Y_test_grid,\
                        parameters_model, Nx, Neumann, EPOCHS,\
                        patience, Nt, train_dt_U, train_dt_P, with_PCA,\
                        Vstar
                    )
                )
            
            # results is a list of pool.ApplyResult objects
            all_results = results
            print ("\n It took", time.time () -a, "to run the model serially")

        #return results
        for j, a, b in all_results:
            if  j == 0:
                Accuracies, Parameters = a, b
            else:
                Accuracies_tmp, Parameters_tmp = a, b
                assert (Parameters_tmp == Parameters)
                Parameters = Parameters_tmp
                Accuracies = np.vstack ([Accuracies, Accuracies_tmp]) 

        try: os.mkdir ("grid_search")
        except: pass
            
        print ("Creating Accuracies and parameter pickled file")
        if with_PCA:
            file_name = "grid_search/PCA_all_grid_search_results_"\
              +str (variable_0) + "_" + str (variable_1) + ".p"
            with open (file_name, 'wb') as save:
                pickle.dump ( (Accuracies, Parameters), save,\
                             protocol = pickle.HIGHEST_PROTOCOL)        
            print ("Statistics pickled to ", file_name)
        else:
            file_name = "grid_search/Normal_all_grid_search_results"\
            + str (variable_0) + "_" + str (variable_1) + ".p"
            with open (file_name, 'wb') as save:
                pickle.dump ((Accuracies, Parameters), save,\
                             protocol = pickle.HIGHEST_PROTOCOL)        
                print ("Statistics pickled to ", file_name)

        os.chdir ("../")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 6/10
# 317/317 [==============================] - 2s 8ms/step - loss: 0.2350 - classify_zero_one: 0.8945 - ||W_U||_{infty} : 1.1004 - ||W_P||_{infty} : 1.2792 - dt_U : 0.4707 - dt_P : 0.3483
#
#
# Accuracy on the validation data 0.8945914
#
# Epoch 7/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2351 - classify_zero_one: 0.8918 - ||W_U||_{infty} : 1.1041 - ||W_P||_{infty} : 1.2908 - dt_U : 0.4676 - dt_P : 0.3421
#
#
# Accuracy on the validation data 0.8941966
#
# Epoch 8/10
# 317/317 [==============================] - 2s 8ms/step - loss: 0.2352 - classify_zero_one: 0.8907 - ||W_U||_{infty} : 1.1061 - ||W_P||_{infty} : 1.2972 - dt_U : 0.4659 - dt_P : 0.3388
#
#
# Accuracy on the validation data 0.89340705
#
# Epoch 9/10
# 317/317 [==============================] - 2s 8ms/step - loss: 0.2352 - classify_zero_one: 0.8905 - ||W_U||_{infty} : 1.1072 - ||W_P||_{infty} : 1.3006 - dt_U : 0.4650 - dt_P : 0.3370
#
#
# Accuracy on the validation data 0.89340705
#
# Epoch 10/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2352 - classify_zero_one: 0.8903 - ||W_U||_{infty} : 1.1078 - ||W_P||_{infty} : 1.3024 - dt_U : 0.4645 - dt_P : 0.3360
#
#
# Accuracy on the validation data 0.89340705
#
#
# End of training
#
# Saving validation data accuracy data
# [0.5282274, 0.95578367, 0.9249901, 0.91077775, 0.9016976, 0.8965653, 0.8945914, 0.8941966, 0.89340705, 0.89340705, 0.89340705]
# Maximal accuracy was 0.95578367
#
# Varying parameters time
#  28
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 392 	layers_K_shared : 4 	lr_U : 0.001 	lr_P : 0.01
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_392_4_0_1_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 4s 8ms/step - loss: 0.2425 - classify_zero_one: 0.6775 - ||W_U||_{infty} : 1.9413 - ||W_P||_{infty} : 1.0000 - dt_U : 0.2223 - dt_P : 0.5700
#
#
# Accuracy on the validation data 0.8033952
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2347 - classify_zero_one: 0.8413 - ||W_U||_{infty} : 3.1473 - ||W_P||_{infty} : 1.0088 - dt_U : 0.0582 - dt_P : 0.5603
#
#
# Accuracy on the validation data 0.85313857
#
# Epoch 3/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2333 - classify_zero_one: 0.8640 - ||W_U||_{infty} : 3.5504 - ||W_P||_{infty} : 1.0685 - dt_U : 0.0453 - dt_P : 0.4996
#
#
# Accuracy on the validation data 0.87129885
#
# Epoch 4/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2339 - classify_zero_one: 0.8800 - ||W_U||_{infty} : 3.8277 - ||W_P||_{infty} : 1.1327 - dt_U : 0.0389 - dt_P : 0.4445
#
#
# Accuracy on the validation data 0.88787997
#
# Epoch 5/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2344 - classify_zero_one: 0.8893 - ||W_U||_{infty} : 4.0000 - ||W_P||_{infty} : 1.1733 - dt_U : 0.0356 - dt_P : 0.4141
#
#
# Accuracy on the validation data 0.89577574
#
# Epoch 6/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2347 - classify_zero_one: 0.8932 - ||W_U||_{infty} : 4.0828 - ||W_P||_{infty} : 1.1952 - dt_U : 0.0342 - dt_P : 0.3991
#
#
# Accuracy on the validation data 0.8993289
#
# Epoch 7/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2348 - classify_zero_one: 0.8957 - ||W_U||_{infty} : 4.1337 - ||W_P||_{infty} : 1.2072 - dt_U : 0.0334 - dt_P : 0.3911
#
#
# Accuracy on the validation data 0.90051323
#
# Epoch 8/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2349 - classify_zero_one: 0.8966 - ||W_U||_{infty} : 4.1580 - ||W_P||_{infty} : 1.2138 - dt_U : 0.0330 - dt_P : 0.3869
#
#
# Accuracy on the validation data 0.9013028
#
# Epoch 9/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2350 - classify_zero_one: 0.8974 - ||W_U||_{infty} : 4.1727 - ||W_P||_{infty} : 1.2174 - dt_U : 0.0327 - dt_P : 0.3846
#
#
# Accuracy on the validation data 0.9016976
#
# Epoch 10/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2350 - classify_zero_one: 0.8980 - ||W_U||_{infty} : 4.1810 - ||W_P||_{infty} : 1.2193 - dt_U : 0.0326 - dt_P : 0.3834
#
#
# Accuracy on the validation data 0.9020924
#
#
# End of training
#
# Saving validation data accuracy data
# [0.40742204, 0.8033952, 0.85313857, 0.87129885, 0.88787997, 0.89577574, 0.8993289, 0.90051323, 0.9013028, 0.9016976, 0.9020924]
# Maximal accuracy was 0.9020924
#
# Varying parameters time
#  29
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 392 	layers_K_shared : 4 	lr_U : 0.001 	lr_P : 0.1
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_392_4_0_2_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 4s 8ms/step - loss: 0.2441 - classify_zero_one: 0.9414 - ||W_U||_{infty} : 8.7608 - ||W_P||_{infty} : 1.0226 - dt_U : 0.0264 - dt_P : 0.5464
#
#
# Accuracy on the validation data 0.98855114
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2411 - classify_zero_one: 0.9841 - ||W_U||_{infty} : 16.8531 - ||W_P||_{infty} : 1.2049 - dt_U : 0.0021 - dt_P : 0.3951
#
#
# Accuracy on the validation data 0.9901303
#
# Epoch 3/10
# 317/317 [==============================] - 2s 8ms/step - loss: 0.2413 - classify_zero_one: 0.9859 - ||W_U||_{infty} : 20.0397 - ||W_P||_{infty} : 1.3408 - dt_U : 0.0014 - dt_P : 0.3175
#
#
# Accuracy on the validation data 0.99052507
#
# Epoch 4/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2415 - classify_zero_one: 0.9866 - ||W_U||_{infty} : 21.6959 - ||W_P||_{infty} : 1.4116 - dt_U : 0.0012 - dt_P : 0.2861
#
#
# Accuracy on the validation data 0.99052507
#
# Epoch 5/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2416 - classify_zero_one: 0.9867 - ||W_U||_{infty} : 22.5671 - ||W_P||_{infty} : 1.4502 - dt_U : 0.0011 - dt_P : 0.2711
#
#
# Accuracy on the validation data 0.99052507
#
# Epoch 6/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2416 - classify_zero_one: 0.9868 - ||W_U||_{infty} : 23.0846 - ||W_P||_{infty} : 1.4716 - dt_U : 0.0011 - dt_P : 0.2632
#
#
# Accuracy on the validation data 0.99052507
#
# Epoch 7/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2416 - classify_zero_one: 0.9869 - ||W_U||_{infty} : 23.3547 - ||W_P||_{infty} : 1.4833 - dt_U : 0.0010 - dt_P : 0.2591
#
#
# Accuracy on the validation data 0.99052507
#
# Epoch 8/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2417 - classify_zero_one: 0.9870 - ||W_U||_{infty} : 23.5129 - ||W_P||_{infty} : 1.4898 - dt_U : 0.0010 - dt_P : 0.2568
#
#
# Accuracy on the validation data 0.99052507
#
# Epoch 9/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2417 - classify_zero_one: 0.9870 - ||W_U||_{infty} : 23.5993 - ||W_P||_{infty} : 1.4933 - dt_U : 0.0010 - dt_P : 0.2556
#
#
# Accuracy on the validation data 0.9909198
#
# Epoch 10/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2417 - classify_zero_one: 0.9870 - ||W_U||_{infty} : 23.6473 - ||W_P||_{infty} : 1.4952 - dt_U : 0.0010 - dt_P : 0.2550
#
#
# Accuracy on the validation data 0.9909198
#
#
# End of training
#
# Saving validation data accuracy data
# [0.4401895, 0.98855114, 0.9901303, 0.99052507, 0.99052507, 0.99052507, 0.99052507, 0.99052507, 0.99052507, 0.9909198, 0.9909198]
# Maximal accuracy was 0.9909198
#
# Varying parameters time
#  30
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 392 	layers_K_shared : 4 	lr_U : 0.01 	lr_P : 0.001
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_392_4_1_0_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 4s 8ms/step - loss: 0.2400 - classify_zero_one: 0.9655 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 2.0071 - dt_U : 0.5700 - dt_P : 0.2012
#
#
# Accuracy on the validation data 0.9652586
#
# Epoch 2/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2433 - classify_zero_one: 0.9540 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 3.2029 - dt_U : 0.5700 - dt_P : 0.0563
#
#
# Accuracy on the validation data 0.94907224
#
# Epoch 3/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2442 - classify_zero_one: 0.9390 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 3.7298 - dt_U : 0.5700 - dt_P : 0.0411
#
#
# Accuracy on the validation data 0.9376234
#
# Epoch 4/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2445 - classify_zero_one: 0.9282 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.0228 - dt_U : 0.5700 - dt_P : 0.0352
#
#
# Accuracy on the validation data 0.9313068
#
# Epoch 5/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2447 - classify_zero_one: 0.9239 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.1937 - dt_U : 0.5700 - dt_P : 0.0324
#
#
# Accuracy on the validation data 0.92735887
#
# Epoch 6/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2448 - classify_zero_one: 0.9210 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.2956 - dt_U : 0.5700 - dt_P : 0.0309
#
#
# Accuracy on the validation data 0.9257797
#
# Epoch 7/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2449 - classify_zero_one: 0.9185 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.3564 - dt_U : 0.5700 - dt_P : 0.0300
#
#
# Accuracy on the validation data 0.92420053
#
# Epoch 8/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2449 - classify_zero_one: 0.9178 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.3925 - dt_U : 0.5700 - dt_P : 0.0295
#
#
# Accuracy on the validation data 0.92341095
#
# Epoch 9/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2450 - classify_zero_one: 0.9166 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.4140 - dt_U : 0.5700 - dt_P : 0.0293
#
#
# Accuracy on the validation data 0.92341095
#
# Epoch 10/10
# 317/317 [==============================] - 2s 8ms/step - loss: 0.2450 - classify_zero_one: 0.9165 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.4266 - dt_U : 0.5700 - dt_P : 0.0291
#
#
# Accuracy on the validation data 0.92341095
#
#
# End of training
#
# Saving validation data accuracy data
# [0.20331623, 0.9652586, 0.94907224, 0.9376234, 0.9313068, 0.92735887, 0.9257797, 0.92420053, 0.92341095, 0.92341095, 0.92341095]
# Maximal accuracy was 0.9652586
#
# Varying parameters time
#  31
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 392 	layers_K_shared : 4 	lr_U : 0.01 	lr_P : 0.01
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_392_4_1_1_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 4s 8ms/step - loss: 0.2401 - classify_zero_one: 0.7163 - ||W_U||_{infty} : 1.5128 - ||W_P||_{infty} : 2.0808 - dt_U : 0.2975 - dt_P : 0.1840
#
#
# Accuracy on the validation data 0.63955784
#
# Epoch 2/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2433 - classify_zero_one: 0.6780 - ||W_U||_{infty} : 2.2337 - ||W_P||_{infty} : 3.2604 - dt_U : 0.1159 - dt_P : 0.0543
#
#
# Accuracy on the validation data 0.70548755
#
# Epoch 3/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2443 - classify_zero_one: 0.7196 - ||W_U||_{infty} : 2.5790 - ||W_P||_{infty} : 3.7685 - dt_U : 0.0859 - dt_P : 0.0402
#
#
# Accuracy on the validation data 0.7283853
#
# Epoch 4/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2447 - classify_zero_one: 0.7396 - ||W_U||_{infty} : 2.7756 - ||W_P||_{infty} : 4.0507 - dt_U : 0.0740 - dt_P : 0.0348
#
#
# Accuracy on the validation data 0.74141335
#
# Epoch 5/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2449 - classify_zero_one: 0.7493 - ||W_U||_{infty} : 2.8727 - ||W_P||_{infty} : 4.2146 - dt_U : 0.0691 - dt_P : 0.0321
#
#
# Accuracy on the validation data 0.7461508
#
# Epoch 6/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2451 - classify_zero_one: 0.7557 - ||W_U||_{infty} : 2.9285 - ||W_P||_{infty} : 4.3113 - dt_U : 0.0665 - dt_P : 0.0307
#
#
# Accuracy on the validation data 0.7516779
#
# Epoch 7/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2451 - classify_zero_one: 0.7591 - ||W_U||_{infty} : 2.9608 - ||W_P||_{infty} : 4.3692 - dt_U : 0.0650 - dt_P : 0.0299
#
#
# Accuracy on the validation data 0.7544414
#
# Epoch 8/10
# 317/317 [==============================] - 2s 8ms/step - loss: 0.2452 - classify_zero_one: 0.7609 - ||W_U||_{infty} : 2.9805 - ||W_P||_{infty} : 4.4040 - dt_U : 0.0642 - dt_P : 0.0294
#
#
# Accuracy on the validation data 0.75523096
#
# Epoch 9/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2452 - classify_zero_one: 0.7615 - ||W_U||_{infty} : 2.9912 - ||W_P||_{infty} : 4.4245 - dt_U : 0.0637 - dt_P : 0.0291
#
#
# Accuracy on the validation data 0.7556257
#
# Epoch 10/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2452 - classify_zero_one: 0.7624 - ||W_U||_{infty} : 2.9981 - ||W_P||_{infty} : 4.4367 - dt_U : 0.0634 - dt_P : 0.0290
#
#
# Accuracy on the validation data 0.75602055
#
#
# End of training
#
# Saving validation data accuracy data
# [0.5732333, 0.63955784, 0.70548755, 0.7283853, 0.74141335, 0.7461508, 0.7516779, 0.7544414, 0.75523096, 0.7556257, 0.75602055]
# Maximal accuracy was 0.75602055
#
# Varying parameters time
#  32
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 392 	layers_K_shared : 4 	lr_U : 0.01 	lr_P : 0.1
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_392_4_1_2_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 5s 9ms/step - loss: 0.2427 - classify_zero_one: 0.9277 - ||W_U||_{infty} : 6.4091 - ||W_P||_{infty} : 2.1308 - dt_U : 0.0294 - dt_P : 0.1706
#
#
# Accuracy on the validation data 0.9778918
#
# Epoch 2/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2448 - classify_zero_one: 0.9754 - ||W_U||_{infty} : 10.1359 - ||W_P||_{infty} : 3.3134 - dt_U : 0.0056 - dt_P : 0.0526
#
#
# Accuracy on the validation data 0.98578763
#
# Epoch 3/10
# 317/317 [==============================] - 3s 11ms/step - loss: 0.2455 - classify_zero_one: 0.9794 - ||W_U||_{infty} : 11.8001 - ||W_P||_{infty} : 3.8469 - dt_U : 0.0041 - dt_P : 0.0386
#
#
# Accuracy on the validation data 0.98736674
#
# Epoch 4/10
# 317/317 [==============================] - 4s 13ms/step - loss: 0.2458 - classify_zero_one: 0.9810 - ||W_U||_{infty} : 12.6934 - ||W_P||_{infty} : 4.1417 - dt_U : 0.0035 - dt_P : 0.0333
#
#
# Accuracy on the validation data 0.98776156
#
# Epoch 5/10
# 317/317 [==============================] - 4s 11ms/step - loss: 0.2459 - classify_zero_one: 0.9815 - ||W_U||_{infty} : 13.1238 - ||W_P||_{infty} : 4.3137 - dt_U : 0.0033 - dt_P : 0.0306
#
#
# Accuracy on the validation data 0.98855114
#
# Epoch 6/10
# 317/317 [==============================] - 5s 16ms/step - loss: 0.2460 - classify_zero_one: 0.9817 - ||W_U||_{infty} : 13.4031 - ||W_P||_{infty} : 4.4160 - dt_U : 0.0032 - dt_P : 0.0292
#
#
# Accuracy on the validation data 0.9893407
#
# Epoch 7/10
# 317/317 [==============================] - 5s 16ms/step - loss: 0.2461 - classify_zero_one: 0.9819 - ||W_U||_{infty} : 13.5664 - ||W_P||_{infty} : 4.4772 - dt_U : 0.0031 - dt_P : 0.0284
#
#
# Accuracy on the validation data 0.9893407
#
# Epoch 8/10
# 317/317 [==============================] - 5s 15ms/step - loss: 0.2461 - classify_zero_one: 0.9818 - ||W_U||_{infty} : 13.6592 - ||W_P||_{infty} : 4.5137 - dt_U : 0.0031 - dt_P : 0.0280
#
#
# Accuracy on the validation data 0.9893407
#
# Epoch 9/10
# 317/317 [==============================] - 6s 19ms/step - loss: 0.2461 - classify_zero_one: 0.9821 - ||W_U||_{infty} : 13.7177 - ||W_P||_{infty} : 4.5354 - dt_U : 0.0030 - dt_P : 0.0277
#
#
# Accuracy on the validation data 0.9893407
#
# Epoch 10/10
# 317/317 [==============================] - 6s 20ms/step - loss: 0.2461 - classify_zero_one: 0.9821 - ||W_U||_{infty} : 13.7529 - ||W_P||_{infty} : 4.5481 - dt_U : 0.0030 - dt_P : 0.0276
#
#
# Accuracy on the validation data 0.9893407
#
#
# End of training
#
# Saving validation data accuracy data
# [0.33714962, 0.9778918, 0.98578763, 0.98736674, 0.98776156, 0.98855114, 0.9893407, 0.9893407, 0.9893407, 0.9893407, 0.9893407]
# Maximal accuracy was 0.9893407
#
# Varying parameters time
#  33
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 392 	layers_K_shared : 4 	lr_U : 0.1 	lr_P : 0.001
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_392_4_2_0_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 5s 11ms/step - loss: 0.2469 - classify_zero_one: 0.9704 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 7.3608 - dt_U : 0.5700 - dt_P : 0.0230
#
#
# Accuracy on the validation data 0.9652586
#
# Epoch 2/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2483 - classify_zero_one: 0.9538 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 11.5898 - dt_U : 0.5700 - dt_P : 0.0043
#
#
# Accuracy on the validation data 0.9498618
#
# Epoch 3/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2485 - classify_zero_one: 0.9398 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 13.5143 - dt_U : 0.5700 - dt_P : 0.0031
#
#
# Accuracy on the validation data 0.94157124
#
# Epoch 4/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2486 - classify_zero_one: 0.9302 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 14.6099 - dt_U : 0.5700 - dt_P : 0.0027
#
#
# Accuracy on the validation data 0.93446505
#
# Epoch 5/10
# 317/317 [==============================] - 4s 11ms/step - loss: 0.2487 - classify_zero_one: 0.9254 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 15.2545 - dt_U : 0.5700 - dt_P : 0.0025
#
#
# Accuracy on the validation data 0.92893803
#
# Epoch 6/10
# 317/317 [==============================] - 4s 11ms/step - loss: 0.2487 - classify_zero_one: 0.9224 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 15.6458 - dt_U : 0.5700 - dt_P : 0.0023
#
#
# Accuracy on the validation data 0.9257797
#
# Epoch 7/10
# 317/317 [==============================] - 4s 12ms/step - loss: 0.2487 - classify_zero_one: 0.9208 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 15.8839 - dt_U : 0.5700 - dt_P : 0.0023
#
#
# Accuracy on the validation data 0.92459536
#
# Epoch 8/10
# 317/317 [==============================] - 5s 17ms/step - loss: 0.2487 - classify_zero_one: 0.9198 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 16.0298 - dt_U : 0.5700 - dt_P : 0.0022
#
#
# Accuracy on the validation data 0.92420053
#
# Epoch 9/10
# 317/317 [==============================] - 4s 14ms/step - loss: 0.2487 - classify_zero_one: 0.9195 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 16.1200 - dt_U : 0.5700 - dt_P : 0.0022
#
#
# Accuracy on the validation data 0.92341095
#
# Epoch 10/10
# 317/317 [==============================] - 4s 12ms/step - loss: 0.2487 - classify_zero_one: 0.9192 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 16.1752 - dt_U : 0.5700 - dt_P : 0.0022
#
#
# Accuracy on the validation data 0.92262137
#
#
# End of training
#
# Saving validation data accuracy data
# [0.46545598, 0.9652586, 0.9498618, 0.94157124, 0.93446505, 0.92893803, 0.9257797, 0.92459536, 0.92420053, 0.92341095, 0.92262137]
# Maximal accuracy was 0.9652586
#
# Varying parameters time
#  34
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 392 	layers_K_shared : 4 	lr_U : 0.1 	lr_P : 0.01
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_392_4_2_1_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 7s 13ms/step - loss: 0.2463 - classify_zero_one: 0.6769 - ||W_U||_{infty} : 1.3603 - ||W_P||_{infty} : 7.2259 - dt_U : 0.3427 - dt_P : 0.0233
#
#
# Accuracy on the validation data 0.5317805
#
# Epoch 2/10
# 317/317 [==============================] - 4s 11ms/step - loss: 0.2484 - classify_zero_one: 0.5385 - ||W_U||_{infty} : 2.0561 - ||W_P||_{infty} : 13.0853 - dt_U : 0.1364 - dt_P : 0.0034
#
#
# Accuracy on the validation data 0.5349388
#
# Epoch 3/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2488 - classify_zero_one: 0.5439 - ||W_U||_{infty} : 2.3662 - ||W_P||_{infty} : 15.6670 - dt_U : 0.1020 - dt_P : 0.0023
#
#
# Accuracy on the validation data 0.54007107
#
# Epoch 4/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2489 - classify_zero_one: 0.5484 - ||W_U||_{infty} : 2.5167 - ||W_P||_{infty} : 16.7698 - dt_U : 0.0900 - dt_P : 0.0020
#
#
# Accuracy on the validation data 0.5432294
#
# Epoch 5/10
# 317/317 [==============================] - 3s 11ms/step - loss: 0.2490 - classify_zero_one: 0.5514 - ||W_U||_{infty} : 2.6084 - ||W_P||_{infty} : 17.4328 - dt_U : 0.0838 - dt_P : 0.0019
#
#
# Accuracy on the validation data 0.54441375
#
# Epoch 6/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2490 - classify_zero_one: 0.5540 - ||W_U||_{infty} : 2.6599 - ||W_P||_{infty} : 17.7926 - dt_U : 0.0806 - dt_P : 0.0018
#
#
# Accuracy on the validation data 0.5455981
#
# Epoch 7/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2490 - classify_zero_one: 0.5548 - ||W_U||_{infty} : 2.6884 - ||W_P||_{infty} : 17.9850 - dt_U : 0.0789 - dt_P : 0.0018
#
#
# Accuracy on the validation data 0.5475721
#
# Epoch 8/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2490 - classify_zero_one: 0.5568 - ||W_U||_{infty} : 2.7062 - ||W_P||_{infty} : 18.1049 - dt_U : 0.0778 - dt_P : 0.0017
#
#
# Accuracy on the validation data 0.549546
#
# Epoch 9/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2490 - classify_zero_one: 0.5576 - ||W_U||_{infty} : 2.7162 - ||W_P||_{infty} : 18.1681 - dt_U : 0.0773 - dt_P : 0.0017
#
#
# Accuracy on the validation data 0.5503356
#
# Epoch 10/10
# 317/317 [==============================] - 2s 8ms/step - loss: 0.2490 - classify_zero_one: 0.5583 - ||W_U||_{infty} : 2.7220 - ||W_P||_{infty} : 18.2034 - dt_U : 0.0769 - dt_P : 0.0017
#
#
# Accuracy on the validation data 0.5503356
#
#
# End of training
#
# Saving validation data accuracy data
# [0.79786813, 0.5317805, 0.5349388, 0.54007107, 0.5432294, 0.54441375, 0.5455981, 0.5475721, 0.549546, 0.5503356, 0.5503356]
# Maximal accuracy was 0.79786813
#
# Varying parameters time
#  35
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 392 	layers_K_shared : 4 	lr_U : 0.1 	lr_P : 0.1
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_392_4_2_2_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 5s 9ms/step - loss: 0.2469 - classify_zero_one: 0.9036 - ||W_U||_{infty} : 4.1894 - ||W_P||_{infty} : 7.3738 - dt_U : 0.0574 - dt_P : 0.0234
#
#
# Accuracy on the validation data 0.9502566
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2485 - classify_zero_one: 0.9602 - ||W_U||_{infty} : 6.6003 - ||W_P||_{infty} : 11.3537 - dt_U : 0.0133 - dt_P : 0.0045
#
#
# Accuracy on the validation data 0.96762735
#
# Epoch 3/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2487 - classify_zero_one: 0.9688 - ||W_U||_{infty} : 7.4996 - ||W_P||_{infty} : 13.1380 - dt_U : 0.0102 - dt_P : 0.0033
#
#
# Accuracy on the validation data 0.9759179
#
# Epoch 4/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2488 - classify_zero_one: 0.9714 - ||W_U||_{infty} : 7.9922 - ||W_P||_{infty} : 14.1658 - dt_U : 0.0089 - dt_P : 0.0028
#
#
# Accuracy on the validation data 0.9790762
#
# Epoch 5/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2489 - classify_zero_one: 0.9731 - ||W_U||_{infty} : 8.2628 - ||W_P||_{infty} : 14.7579 - dt_U : 0.0084 - dt_P : 0.0026
#
#
# Accuracy on the validation data 0.9806554
#
# Epoch 6/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2489 - classify_zero_one: 0.9743 - ||W_U||_{infty} : 8.4316 - ||W_P||_{infty} : 15.1209 - dt_U : 0.0080 - dt_P : 0.0025
#
#
# Accuracy on the validation data 0.98105013
#
# Epoch 7/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2489 - classify_zero_one: 0.9750 - ||W_U||_{infty} : 8.5214 - ||W_P||_{infty} : 15.3412 - dt_U : 0.0078 - dt_P : 0.0024
#
#
# Accuracy on the validation data 0.98105013
#
# Epoch 8/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2489 - classify_zero_one: 0.9753 - ||W_U||_{infty} : 8.5740 - ||W_P||_{infty} : 15.4775 - dt_U : 0.0078 - dt_P : 0.0024
#
#
# Accuracy on the validation data 0.98105013
#
# Epoch 9/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2489 - classify_zero_one: 0.9754 - ||W_U||_{infty} : 8.6057 - ||W_P||_{infty} : 15.5602 - dt_U : 0.0077 - dt_P : 0.0024
#
#
# Accuracy on the validation data 0.98144495
#
# Epoch 10/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2489 - classify_zero_one: 0.9754 - ||W_U||_{infty} : 8.6262 - ||W_P||_{infty} : 15.6105 - dt_U : 0.0077 - dt_P : 0.0023
#
#
# Accuracy on the validation data 0.98144495
#
#
# End of training
#
# Saving validation data accuracy data
# [0.55073035, 0.9502566, 0.96762735, 0.9759179, 0.9790762, 0.9806554, 0.98105013, 0.98105013, 0.98105013, 0.98144495, 0.98144495]
# Maximal accuracy was 0.98144495
#
# Varying parameters time
#  36
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 196 	layers_K_shared : 1 	lr_U : 0.001 	lr_P : 0.001
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_196_1_0_0_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 5s 10ms/step - loss: 0.2426 - classify_zero_one: 0.9659 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 1.0000 - dt_U : 0.5700 - dt_P : 0.5700
#
#
# Accuracy on the validation data 0.95538884
#
# Epoch 2/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2360 - classify_zero_one: 0.9238 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 1.0751 - dt_U : 0.5700 - dt_P : 0.4967
#
#
# Accuracy on the validation data 0.913936
#
# Epoch 3/10
# 317/317 [==============================] - 4s 12ms/step - loss: 0.2365 - classify_zero_one: 0.8950 - ||W_U||_{infty} : 1.0155 - ||W_P||_{infty} : 1.2091 - dt_U : 0.5529 - dt_P : 0.3905
#
#
# Accuracy on the validation data 0.8902487
#
# Epoch 4/10
# 317/317 [==============================] - 4s 13ms/step - loss: 0.2368 - classify_zero_one: 0.8836 - ||W_U||_{infty} : 1.0455 - ||W_P||_{infty} : 1.2767 - dt_U : 0.5215 - dt_P : 0.3498
#
#
# Accuracy on the validation data 0.8780103
#
# Epoch 5/10
# 317/317 [==============================] - 4s 13ms/step - loss: 0.2370 - classify_zero_one: 0.8750 - ||W_U||_{infty} : 1.0605 - ||W_P||_{infty} : 1.3129 - dt_U : 0.5068 - dt_P : 0.3307
#
#
# Accuracy on the validation data 0.8724832
#
# Epoch 6/10
# 317/317 [==============================] - 4s 13ms/step - loss: 0.2371 - classify_zero_one: 0.8714 - ||W_U||_{infty} : 1.0684 - ||W_P||_{infty} : 1.3328 - dt_U : 0.4994 - dt_P : 0.3209
#
#
# Accuracy on the validation data 0.86853534
#
# Epoch 7/10
# 317/317 [==============================] - 4s 12ms/step - loss: 0.2371 - classify_zero_one: 0.8700 - ||W_U||_{infty} : 1.0727 - ||W_P||_{infty} : 1.3437 - dt_U : 0.4954 - dt_P : 0.3157
#
#
# Accuracy on the validation data 0.8669562
#
# Epoch 8/10
# 317/317 [==============================] - 4s 13ms/step - loss: 0.2372 - classify_zero_one: 0.8691 - ||W_U||_{infty} : 1.0748 - ||W_P||_{infty} : 1.3497 - dt_U : 0.4934 - dt_P : 0.3129
#
#
# Accuracy on the validation data 0.8669562
#
# Epoch 9/10
# 317/317 [==============================] - 5s 15ms/step - loss: 0.2372 - classify_zero_one: 0.8689 - ||W_U||_{infty} : 1.0760 - ||W_P||_{infty} : 1.3529 - dt_U : 0.4923 - dt_P : 0.3114
#
#
# Accuracy on the validation data 0.86577183
#
# Epoch 10/10
# 317/317 [==============================] - 4s 13ms/step - loss: 0.2372 - classify_zero_one: 0.8685 - ||W_U||_{infty} : 1.0766 - ||W_P||_{infty} : 1.3547 - dt_U : 0.4918 - dt_P : 0.3106
#
#
# Accuracy on the validation data 0.86498225
#
#
# End of training
#
# Saving validation data accuracy data
# [0.6825898, 0.95538884, 0.913936, 0.8902487, 0.8780103, 0.8724832, 0.86853534, 0.8669562, 0.8669562, 0.86577183, 0.86498225]
# Maximal accuracy was 0.95538884
#
# Varying parameters time
#  37
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 196 	layers_K_shared : 1 	lr_U : 0.001 	lr_P : 0.01
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_196_1_0_1_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 7s 14ms/step - loss: 0.2424 - classify_zero_one: 0.7427 - ||W_U||_{infty} : 1.7322 - ||W_P||_{infty} : 1.0061 - dt_U : 0.2543 - dt_P : 0.5634
#
#
# Accuracy on the validation data 0.70746154
#
# Epoch 2/10
# 317/317 [==============================] - 4s 13ms/step - loss: 0.2382 - classify_zero_one: 0.7692 - ||W_U||_{infty} : 2.8937 - ||W_P||_{infty} : 1.1239 - dt_U : 0.0691 - dt_P : 0.4534
#
#
# Accuracy on the validation data 0.80457956
#
# Epoch 3/10
# 317/317 [==============================] - 4s 12ms/step - loss: 0.2388 - classify_zero_one: 0.8186 - ||W_U||_{infty} : 3.4270 - ||W_P||_{infty} : 1.2487 - dt_U : 0.0487 - dt_P : 0.3661
#
#
# Accuracy on the validation data 0.8310304
#
# Epoch 4/10
# 317/317 [==============================] - 4s 11ms/step - loss: 0.2392 - classify_zero_one: 0.8399 - ||W_U||_{infty} : 3.6899 - ||W_P||_{infty} : 1.3156 - dt_U : 0.0419 - dt_P : 0.3295
#
#
# Accuracy on the validation data 0.8409001
#
# Epoch 5/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2394 - classify_zero_one: 0.8483 - ||W_U||_{infty} : 3.8312 - ||W_P||_{infty} : 1.3519 - dt_U : 0.0388 - dt_P : 0.3119
#
#
# Accuracy on the validation data 0.8491907
#
# Epoch 6/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2395 - classify_zero_one: 0.8524 - ||W_U||_{infty} : 3.9065 - ||W_P||_{infty} : 1.3721 - dt_U : 0.0374 - dt_P : 0.3028
#
#
# Accuracy on the validation data 0.8515594
#
# Epoch 7/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2396 - classify_zero_one: 0.8546 - ||W_U||_{infty} : 3.9522 - ||W_P||_{infty} : 1.3834 - dt_U : 0.0365 - dt_P : 0.2978
#
#
# Accuracy on the validation data 0.8535334
#
# Epoch 8/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2396 - classify_zero_one: 0.8556 - ||W_U||_{infty} : 3.9771 - ||W_P||_{infty} : 1.3896 - dt_U : 0.0360 - dt_P : 0.2952
#
#
# Accuracy on the validation data 0.8555073
#
# Epoch 9/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2396 - classify_zero_one: 0.8563 - ||W_U||_{infty} : 3.9908 - ||W_P||_{infty} : 1.3931 - dt_U : 0.0358 - dt_P : 0.2937
#
#
# Accuracy on the validation data 0.8570865
#
# Epoch 10/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2396 - classify_zero_one: 0.8566 - ||W_U||_{infty} : 3.9983 - ||W_P||_{infty} : 1.3949 - dt_U : 0.0357 - dt_P : 0.2929
#
#
# Accuracy on the validation data 0.8570865
#
#
# End of training
#
# Saving validation data accuracy data
# [0.6648243, 0.70746154, 0.80457956, 0.8310304, 0.8409001, 0.8491907, 0.8515594, 0.8535334, 0.8555073, 0.8570865, 0.8570865]
# Maximal accuracy was 0.8570865
#
# Varying parameters time
#  38
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 196 	layers_K_shared : 1 	lr_U : 0.001 	lr_P : 0.1
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_196_1_0_2_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 4s 9ms/step - loss: 0.2437 - classify_zero_one: 0.9020 - ||W_U||_{infty} : 7.7560 - ||W_P||_{infty} : 1.0000 - dt_U : 0.0343 - dt_P : 0.5700
#
#
# Accuracy on the validation data 0.98144495
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2380 - classify_zero_one: 0.9778 - ||W_U||_{infty} : 15.5343 - ||W_P||_{infty} : 1.0549 - dt_U : 0.0024 - dt_P : 0.5134
#
#
# Accuracy on the validation data 0.9861824
#
# Epoch 3/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2379 - classify_zero_one: 0.9809 - ||W_U||_{infty} : 19.2095 - ||W_P||_{infty} : 1.1592 - dt_U : 0.0016 - dt_P : 0.4250
#
#
# Accuracy on the validation data 0.986972
#
# Epoch 4/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2384 - classify_zero_one: 0.9817 - ||W_U||_{infty} : 20.8977 - ||W_P||_{infty} : 1.2317 - dt_U : 0.0013 - dt_P : 0.3759
#
#
# Accuracy on the validation data 0.986972
#
# Epoch 5/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2386 - classify_zero_one: 0.9817 - ||W_U||_{infty} : 21.7587 - ||W_P||_{infty} : 1.2701 - dt_U : 0.0012 - dt_P : 0.3534
#
#
# Accuracy on the validation data 0.986972
#
# Epoch 6/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2387 - classify_zero_one: 0.9821 - ||W_U||_{infty} : 22.2486 - ||W_P||_{infty} : 1.2912 - dt_U : 0.0012 - dt_P : 0.3419
#
#
# Accuracy on the validation data 0.986972
#
# Epoch 7/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2388 - classify_zero_one: 0.9821 - ||W_U||_{infty} : 22.5156 - ||W_P||_{infty} : 1.3028 - dt_U : 0.0011 - dt_P : 0.3358
#
#
# Accuracy on the validation data 0.98736674
#
# Epoch 8/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2388 - classify_zero_one: 0.9820 - ||W_U||_{infty} : 22.6725 - ||W_P||_{infty} : 1.3092 - dt_U : 0.0011 - dt_P : 0.3325
#
#
# Accuracy on the validation data 0.98736674
#
# Epoch 9/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2389 - classify_zero_one: 0.9820 - ||W_U||_{infty} : 22.7524 - ||W_P||_{infty} : 1.3127 - dt_U : 0.0011 - dt_P : 0.3308
#
#
# Accuracy on the validation data 0.98736674
#
# Epoch 10/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2389 - classify_zero_one: 0.9821 - ||W_U||_{infty} : 22.7991 - ||W_P||_{infty} : 1.3146 - dt_U : 0.0011 - dt_P : 0.3298
#
#
# Accuracy on the validation data 0.98736674
#
#
# End of training
#
# Saving validation data accuracy data
# [0.6316621, 0.98144495, 0.9861824, 0.986972, 0.986972, 0.986972, 0.986972, 0.98736674, 0.98736674, 0.98736674, 0.98736674]
# Maximal accuracy was 0.98736674
#
# Varying parameters time
#  39
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 196 	layers_K_shared : 1 	lr_U : 0.01 	lr_P : 0.001
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_196_1_1_0_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 5s 9ms/step - loss: 0.2417 - classify_zero_one: 0.9688 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 2.1011 - dt_U : 0.5700 - dt_P : 0.1808
#
#
# Accuracy on the validation data 0.9632847
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2441 - classify_zero_one: 0.9400 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 3.2995 - dt_U : 0.5700 - dt_P : 0.0530
#
#
# Accuracy on the validation data 0.9328859
#
# Epoch 3/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2448 - classify_zero_one: 0.9196 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 3.8444 - dt_U : 0.5700 - dt_P : 0.0387
#
#
# Accuracy on the validation data 0.9166996
#
# Epoch 4/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2452 - classify_zero_one: 0.9044 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.1552 - dt_U : 0.5700 - dt_P : 0.0330
#
#
# Accuracy on the validation data 0.9040663
#
# Epoch 5/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2454 - classify_zero_one: 0.8980 - ||W_U||_{infty} : 1.0019 - ||W_P||_{infty} : 4.3362 - dt_U : 0.5679 - dt_P : 0.0303
#
#
# Accuracy on the validation data 0.89893407
#
# Epoch 6/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2455 - classify_zero_one: 0.8930 - ||W_U||_{infty} : 1.0085 - ||W_P||_{infty} : 4.4435 - dt_U : 0.5604 - dt_P : 0.0289
#
#
# Accuracy on the validation data 0.89696014
#
# Epoch 7/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2455 - classify_zero_one: 0.8915 - ||W_U||_{infty} : 1.0125 - ||W_P||_{infty} : 4.5073 - dt_U : 0.5560 - dt_P : 0.0281
#
#
# Accuracy on the validation data 0.89498615
#
# Epoch 8/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2456 - classify_zero_one: 0.8900 - ||W_U||_{infty} : 1.0147 - ||W_P||_{infty} : 4.5453 - dt_U : 0.5536 - dt_P : 0.0276
#
#
# Accuracy on the validation data 0.8945914
#
# Epoch 9/10
# 317/317 [==============================] - 3s 11ms/step - loss: 0.2456 - classify_zero_one: 0.8893 - ||W_U||_{infty} : 1.0159 - ||W_P||_{infty} : 4.5678 - dt_U : 0.5523 - dt_P : 0.0273
#
#
# Accuracy on the validation data 0.8945914
#
# Epoch 10/10
# 317/317 [==============================] - 3s 10ms/step - loss: 0.2456 - classify_zero_one: 0.8891 - ||W_U||_{infty} : 1.0165 - ||W_P||_{infty} : 4.5808 - dt_U : 0.5517 - dt_P : 0.0272
#
#
# Accuracy on the validation data 0.8945914
#
#
# End of training
#
# Saving validation data accuracy data
# [0.4330833, 0.9632847, 0.9328859, 0.9166996, 0.9040663, 0.89893407, 0.89696014, 0.89498615, 0.8945914, 0.8945914, 0.8945914]
# Maximal accuracy was 0.9632847
#
# Varying parameters time
#  40
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 196 	layers_K_shared : 1 	lr_U : 0.01 	lr_P : 0.01
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_196_1_1_1_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 5s 9ms/step - loss: 0.2414 - classify_zero_one: 0.7201 - ||W_U||_{infty} : 1.5807 - ||W_P||_{infty} : 2.1424 - dt_U : 0.2684 - dt_P : 0.1740
#
#
# Accuracy on the validation data 0.65337545
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2442 - classify_zero_one: 0.6786 - ||W_U||_{infty} : 2.3809 - ||W_P||_{infty} : 3.3674 - dt_U : 0.1018 - dt_P : 0.0509
#
#
# Accuracy on the validation data 0.69522303
#
# Epoch 3/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2451 - classify_zero_one: 0.7081 - ||W_U||_{infty} : 2.7052 - ||W_P||_{infty} : 3.8985 - dt_U : 0.0780 - dt_P : 0.0376
#
#
# Accuracy on the validation data 0.71575207
#
# Epoch 4/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2454 - classify_zero_one: 0.7228 - ||W_U||_{infty} : 2.8809 - ||W_P||_{infty} : 4.1929 - dt_U : 0.0687 - dt_P : 0.0324
#
#
# Accuracy on the validation data 0.72404265
#
# Epoch 5/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2456 - classify_zero_one: 0.7308 - ||W_U||_{infty} : 2.9756 - ||W_P||_{infty} : 4.3630 - dt_U : 0.0644 - dt_P : 0.0300
#
#
# Accuracy on the validation data 0.7323332
#
# Epoch 6/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2457 - classify_zero_one: 0.7368 - ||W_U||_{infty} : 3.0265 - ||W_P||_{infty} : 4.4646 - dt_U : 0.0622 - dt_P : 0.0286
#
#
# Accuracy on the validation data 0.7362811
#
# Epoch 7/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2458 - classify_zero_one: 0.7393 - ||W_U||_{infty} : 3.0592 - ||W_P||_{infty} : 4.5251 - dt_U : 0.0609 - dt_P : 0.0278
#
#
# Accuracy on the validation data 0.73786026
#
# Epoch 8/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2458 - classify_zero_one: 0.7412 - ||W_U||_{infty} : 3.0778 - ||W_P||_{infty} : 4.5613 - dt_U : 0.0602 - dt_P : 0.0274
#
#
# Accuracy on the validation data 0.7394394
#
# Epoch 9/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2459 - classify_zero_one: 0.7423 - ||W_U||_{infty} : 3.0884 - ||W_P||_{infty} : 4.5828 - dt_U : 0.0598 - dt_P : 0.0271
#
#
# Accuracy on the validation data 0.74141335
#
# Epoch 10/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2459 - classify_zero_one: 0.7430 - ||W_U||_{infty} : 3.0943 - ||W_P||_{infty} : 4.5954 - dt_U : 0.0595 - dt_P : 0.0270
#
#
# Accuracy on the validation data 0.7418081
#
#
# End of training
#
# Saving validation data accuracy data
# [0.76983815, 0.65337545, 0.69522303, 0.71575207, 0.72404265, 0.7323332, 0.7362811, 0.73786026, 0.7394394, 0.74141335, 0.7418081]
# Maximal accuracy was 0.76983815
#
# Varying parameters time
#  41
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 196 	layers_K_shared : 1 	lr_U : 0.01 	lr_P : 0.1
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_196_1_1_2_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 5s 9ms/step - loss: 0.2416 - classify_zero_one: 0.9008 - ||W_U||_{infty} : 7.5874 - ||W_P||_{infty} : 2.0031 - dt_U : 0.0245 - dt_P : 0.1922
#
#
# Accuracy on the validation data 0.96288985
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2444 - classify_zero_one: 0.9618 - ||W_U||_{infty} : 10.9898 - ||W_P||_{infty} : 3.1820 - dt_U : 0.0048 - dt_P : 0.0571
#
#
# Accuracy on the validation data 0.9723648
#
# Epoch 3/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2453 - classify_zero_one: 0.9680 - ||W_U||_{infty} : 12.3253 - ||W_P||_{infty} : 3.7359 - dt_U : 0.0038 - dt_P : 0.0410
#
#
# Accuracy on the validation data 0.9751283
#
# Epoch 4/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2457 - classify_zero_one: 0.9700 - ||W_U||_{infty} : 13.0639 - ||W_P||_{infty} : 4.0411 - dt_U : 0.0033 - dt_P : 0.0349
#
#
# Accuracy on the validation data 0.97670746
#
# Epoch 5/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2459 - classify_zero_one: 0.9710 - ||W_U||_{infty} : 13.4590 - ||W_P||_{infty} : 4.2177 - dt_U : 0.0031 - dt_P : 0.0320
#
#
# Accuracy on the validation data 0.9778918
#
# Epoch 6/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2460 - classify_zero_one: 0.9714 - ||W_U||_{infty} : 13.6933 - ||W_P||_{infty} : 4.3213 - dt_U : 0.0030 - dt_P : 0.0305
#
#
# Accuracy on the validation data 0.9782866
#
# Epoch 7/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2460 - classify_zero_one: 0.9716 - ||W_U||_{infty} : 13.8224 - ||W_P||_{infty} : 4.3831 - dt_U : 0.0030 - dt_P : 0.0297
#
#
# Accuracy on the validation data 0.9782866
#
# Epoch 8/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2460 - classify_zero_one: 0.9719 - ||W_U||_{infty} : 13.9000 - ||W_P||_{infty} : 4.4199 - dt_U : 0.0030 - dt_P : 0.0292
#
#
# Accuracy on the validation data 0.9782866
#
# Epoch 9/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2461 - classify_zero_one: 0.9719 - ||W_U||_{infty} : 13.9470 - ||W_P||_{infty} : 4.4418 - dt_U : 0.0029 - dt_P : 0.0289
#
#
# Accuracy on the validation data 0.9782866
#
# Epoch 10/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2461 - classify_zero_one: 0.9719 - ||W_U||_{infty} : 13.9731 - ||W_P||_{infty} : 4.4545 - dt_U : 0.0029 - dt_P : 0.0287
#
#
# Accuracy on the validation data 0.9782866
#
#
# End of training
#
# Saving validation data accuracy data
# [0.15357284, 0.96288985, 0.9723648, 0.9751283, 0.97670746, 0.9778918, 0.9782866, 0.9782866, 0.9782866, 0.9782866, 0.9782866]
# Maximal accuracy was 0.9782866
#
# Varying parameters time
#  42
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 196 	layers_K_shared : 1 	lr_U : 0.1 	lr_P : 0.001
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_196_1_2_0_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 5s 9ms/step - loss: 0.2473 - classify_zero_one: 0.9741 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 7.8423 - dt_U : 0.5700 - dt_P : 0.0210
#
#
# Accuracy on the validation data 0.97394395
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2486 - classify_zero_one: 0.9620 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 12.6213 - dt_U : 0.5700 - dt_P : 0.0036
#
#
# Accuracy on the validation data 0.96210027
#
# Epoch 3/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2488 - classify_zero_one: 0.9517 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 14.7328 - dt_U : 0.5700 - dt_P : 0.0026
#
#
# Accuracy on the validation data 0.9542045
#
# Epoch 4/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2489 - classify_zero_one: 0.9462 - ||W_U||_{infty} : 1.0027 - ||W_P||_{infty} : 15.9099 - dt_U : 0.5670 - dt_P : 0.0023
#
#
# Accuracy on the validation data 0.94946706
#
# Epoch 5/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2490 - classify_zero_one: 0.9429 - ||W_U||_{infty} : 1.0111 - ||W_P||_{infty} : 16.6067 - dt_U : 0.5576 - dt_P : 0.0021
#
#
# Accuracy on the validation data 0.94630873
#
# Epoch 6/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2490 - classify_zero_one: 0.9402 - ||W_U||_{infty} : 1.0163 - ||W_P||_{infty} : 17.0261 - dt_U : 0.5519 - dt_P : 0.0020
#
#
# Accuracy on the validation data 0.94394
#
# Epoch 7/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2490 - classify_zero_one: 0.9382 - ||W_U||_{infty} : 1.0191 - ||W_P||_{infty} : 17.2788 - dt_U : 0.5488 - dt_P : 0.0019
#
#
# Accuracy on the validation data 0.94275564
#
# Epoch 8/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2490 - classify_zero_one: 0.9373 - ||W_U||_{infty} : 1.0208 - ||W_P||_{infty} : 17.4342 - dt_U : 0.5470 - dt_P : 0.0019
#
#
# Accuracy on the validation data 0.9423608
#
# Epoch 9/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2490 - classify_zero_one: 0.9369 - ||W_U||_{infty} : 1.0217 - ||W_P||_{infty} : 17.5269 - dt_U : 0.5460 - dt_P : 0.0019
#
#
# Accuracy on the validation data 0.9423608
#
# Epoch 10/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2490 - classify_zero_one: 0.9369 - ||W_U||_{infty} : 1.0222 - ||W_P||_{infty} : 17.5832 - dt_U : 0.5455 - dt_P : 0.0018
#
#
# Accuracy on the validation data 0.9423608
#
#
# End of training
#
# Saving validation data accuracy data
# [0.26490328, 0.97394395, 0.96210027, 0.9542045, 0.94946706, 0.94630873, 0.94394, 0.94275564, 0.9423608, 0.9423608, 0.9423608]
# Maximal accuracy was 0.97394395
#
# Varying parameters time
#  43
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 196 	layers_K_shared : 1 	lr_U : 0.1 	lr_P : 0.01
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_196_1_2_1_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 4s 9ms/step - loss: 0.2466 - classify_zero_one: 0.8454 - ||W_U||_{infty} : 1.2875 - ||W_P||_{infty} : 7.1425 - dt_U : 0.3852 - dt_P : 0.0242
#
#
# Accuracy on the validation data 0.67548364
#
# Epoch 2/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2483 - classify_zero_one: 0.6947 - ||W_U||_{infty} : 2.2412 - ||W_P||_{infty} : 11.9306 - dt_U : 0.1158 - dt_P : 0.0041
#
#
# Accuracy on the validation data 0.7078563
#
# Epoch 3/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2487 - classify_zero_one: 0.7206 - ||W_U||_{infty} : 2.6021 - ||W_P||_{infty} : 14.1853 - dt_U : 0.0845 - dt_P : 0.0028
#
#
# Accuracy on the validation data 0.7291749
#
# Epoch 4/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2489 - classify_zero_one: 0.7384 - ||W_U||_{infty} : 2.8200 - ||W_P||_{infty} : 15.4291 - dt_U : 0.0717 - dt_P : 0.0024
#
#
# Accuracy on the validation data 0.74022895
#
# Epoch 5/10
# 317/317 [==============================] - 3s 9ms/step - loss: 0.2489 - classify_zero_one: 0.7459 - ||W_U||_{infty} : 2.9153 - ||W_P||_{infty} : 16.0070 - dt_U : 0.0671 - dt_P : 0.0022
#
#
# Accuracy on the validation data 0.7473352
#
# Epoch 6/10
# 317/317 [==============================] - 3s 8ms/step - loss: 0.2489 - classify_zero_one: 0.7503 - ||W_U||_{infty} : 2.9716 - ||W_P||_{infty} : 16.3534 - dt_U : 0.0646 - dt_P : 0.0021
#
#
# Accuracy on the validation data 0.7500987
#
# Epoch 7/10
# ...
#
# Epoch 8/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2455 - classify_zero_one: 0.7508 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.0711 - dt_U : 0.5700 - dt_P : 0.0344
#
#
# Accuracy on the validation data 0.74851954
#
# Epoch 9/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2455 - classify_zero_one: 0.7497 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.0887 - dt_U : 0.5700 - dt_P : 0.0341
#
#
# Accuracy on the validation data 0.74772996
#
# Epoch 10/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2455 - classify_zero_one: 0.7491 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 4.0985 - dt_U : 0.5700 - dt_P : 0.0339
#
#
# Accuracy on the validation data 0.74772996
#
#
# End of training
#
# Saving validation data accuracy data
# [0.8910383, 0.8515594, 0.8065535, 0.77891827, 0.7647059, 0.7591788, 0.7544414, 0.75128305, 0.74851954, 0.74772996, 0.74772996]
# Maximal accuracy was 0.8910383
#
# Varying parameters time
#  85
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 49 	layers_K_shared : 4 	lr_U : 0.01 	lr_P : 0.01
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_49_4_1_1_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 3s 5ms/step - loss: 0.2396 - classify_zero_one: 0.6217 - ||W_U||_{infty} : 1.4755 - ||W_P||_{infty} : 1.7029 - dt_U : 0.3169 - dt_P : 0.2465
#
#
# Accuracy on the validation data 0.57994473
#
# Epoch 2/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2427 - classify_zero_one: 0.6049 - ||W_U||_{infty} : 2.2816 - ||W_P||_{infty} : 2.7228 - dt_U : 0.1107 - dt_P : 0.0779
#
#
# Accuracy on the validation data 0.6190288
#
# Epoch 3/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2439 - classify_zero_one: 0.6340 - ||W_U||_{infty} : 2.6599 - ||W_P||_{infty} : 3.1899 - dt_U : 0.0808 - dt_P : 0.0562
#
#
# Accuracy on the validation data 0.6363995
#
# Epoch 4/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2444 - classify_zero_one: 0.6483 - ||W_U||_{infty} : 2.8512 - ||W_P||_{infty} : 3.4347 - dt_U : 0.0702 - dt_P : 0.0483
#
#
# Accuracy on the validation data 0.6439005
#
# Epoch 5/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2446 - classify_zero_one: 0.6554 - ||W_U||_{infty} : 2.9577 - ||W_P||_{infty} : 3.5735 - dt_U : 0.0652 - dt_P : 0.0446
#
#
# Accuracy on the validation data 0.6478484
#
# Epoch 6/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2448 - classify_zero_one: 0.6590 - ||W_U||_{infty} : 3.0186 - ||W_P||_{infty} : 3.6551 - dt_U : 0.0626 - dt_P : 0.0427
#
#
# Accuracy on the validation data 0.65061194
#
# Epoch 7/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2448 - classify_zero_one: 0.6613 - ||W_U||_{infty} : 3.0529 - ||W_P||_{infty} : 3.7022 - dt_U : 0.0612 - dt_P : 0.0416
#
#
# Accuracy on the validation data 0.65258586
#
# Epoch 8/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2449 - classify_zero_one: 0.6622 - ||W_U||_{infty} : 3.0742 - ||W_P||_{infty} : 3.7310 - dt_U : 0.0603 - dt_P : 0.0409
#
#
# Accuracy on the validation data 0.6545598
#
# Epoch 9/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2449 - classify_zero_one: 0.6633 - ||W_U||_{infty} : 3.0861 - ||W_P||_{infty} : 3.7476 - dt_U : 0.0598 - dt_P : 0.0406
#
#
# Accuracy on the validation data 0.65613896
#
# Epoch 10/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2449 - classify_zero_one: 0.6638 - ||W_U||_{infty} : 3.0933 - ||W_P||_{infty} : 3.7573 - dt_U : 0.0596 - dt_P : 0.0404
#
#
# Accuracy on the validation data 0.65692854
#
#
# End of training
#
# Saving validation data accuracy data
# [0.15594158, 0.57994473, 0.6190288, 0.6363995, 0.6439005, 0.6478484, 0.65061194, 0.65258586, 0.6545598, 0.65613896, 0.65692854]
# Maximal accuracy was 0.65692854
#
# Varying parameters time
#  86
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 49 	layers_K_shared : 4 	lr_U : 0.01 	lr_P : 0.1
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_49_4_1_2_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 3s 5ms/step - loss: 0.2389 - classify_zero_one: 0.7780 - ||W_U||_{infty} : 6.9820 - ||W_P||_{infty} : 1.5142 - dt_U : 0.0286 - dt_P : 0.2920
#
#
# Accuracy on the validation data 0.8555073
#
# Epoch 2/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2408 - classify_zero_one: 0.8667 - ||W_U||_{infty} : 11.4116 - ||W_P||_{infty} : 2.2756 - dt_U : 0.0044 - dt_P : 0.1113
#
#
# Accuracy on the validation data 0.8744572
#
# Epoch 3/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2418 - classify_zero_one: 0.8782 - ||W_U||_{infty} : 13.0218 - ||W_P||_{infty} : 2.6332 - dt_U : 0.0034 - dt_P : 0.0824
#
#
# Accuracy on the validation data 0.8835373
#
# Epoch 4/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2423 - classify_zero_one: 0.8833 - ||W_U||_{infty} : 13.9092 - ||W_P||_{infty} : 2.8300 - dt_U : 0.0029 - dt_P : 0.0712
#
#
# Accuracy on the validation data 0.8870904
#
# Epoch 5/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2425 - classify_zero_one: 0.8852 - ||W_U||_{infty} : 14.4172 - ||W_P||_{infty} : 2.9430 - dt_U : 0.0027 - dt_P : 0.0658
#
#
# Accuracy on the validation data 0.8882748
#
# Epoch 6/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2427 - classify_zero_one: 0.8869 - ||W_U||_{infty} : 14.7075 - ||W_P||_{infty} : 3.0098 - dt_U : 0.0026 - dt_P : 0.0629
#
#
# Accuracy on the validation data 0.88945913
#
# Epoch 7/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2427 - classify_zero_one: 0.8877 - ||W_U||_{infty} : 14.8815 - ||W_P||_{infty} : 3.0487 - dt_U : 0.0026 - dt_P : 0.0613
#
#
# Accuracy on the validation data 0.8902487
#
# Epoch 8/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2428 - classify_zero_one: 0.8882 - ||W_U||_{infty} : 14.9903 - ||W_P||_{infty} : 3.0716 - dt_U : 0.0025 - dt_P : 0.0604
#
#
# Accuracy on the validation data 0.8910383
#
# Epoch 9/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2428 - classify_zero_one: 0.8883 - ||W_U||_{infty} : 15.0516 - ||W_P||_{infty} : 3.0848 - dt_U : 0.0025 - dt_P : 0.0599
#
#
# Accuracy on the validation data 0.8918279
#
# Epoch 10/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2428 - classify_zero_one: 0.8885 - ||W_U||_{infty} : 15.0875 - ||W_P||_{infty} : 3.0924 - dt_U : 0.0025 - dt_P : 0.0596
#
#
# Accuracy on the validation data 0.89222264
#
#
# End of training
#
# Saving validation data accuracy data
# [0.42795104, 0.8555073, 0.8744572, 0.8835373, 0.8870904, 0.8882748, 0.88945913, 0.8902487, 0.8910383, 0.8918279, 0.89222264]
# Maximal accuracy was 0.89222264
#
# Varying parameters time
#  87
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 49 	layers_K_shared : 4 	lr_U : 0.1 	lr_P : 0.001
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_49_4_2_0_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 3s 5ms/step - loss: 0.2463 - classify_zero_one: 0.8645 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 6.1410 - dt_U : 0.5700 - dt_P : 0.0347
#
#
# Accuracy on the validation data 0.8424793
#
# Epoch 2/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2484 - classify_zero_one: 0.8230 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 10.7189 - dt_U : 0.5700 - dt_P : 0.0051
#
#
# Accuracy on the validation data 0.8085274
#
# Epoch 3/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2488 - classify_zero_one: 0.7966 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 13.2554 - dt_U : 0.5700 - dt_P : 0.0033
#
#
# Accuracy on the validation data 0.78602445
#
# Epoch 4/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2490 - classify_zero_one: 0.7822 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 14.5493 - dt_U : 0.5700 - dt_P : 0.0027
#
#
# Accuracy on the validation data 0.7781287
#
# Epoch 5/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2490 - classify_zero_one: 0.7735 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 15.2795 - dt_U : 0.5700 - dt_P : 0.0024
#
#
# Accuracy on the validation data 0.7714173
#
# Epoch 6/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2491 - classify_zero_one: 0.7695 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 15.7194 - dt_U : 0.5700 - dt_P : 0.0023
#
#
# Accuracy on the validation data 0.76786417
#
# Epoch 7/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2491 - classify_zero_one: 0.7674 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 15.9774 - dt_U : 0.5700 - dt_P : 0.0022
#
#
# Accuracy on the validation data 0.7666798
#
# Epoch 8/10
# 317/317 [==============================] - 1s 5ms/step - loss: 0.2491 - classify_zero_one: 0.7655 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 16.1299 - dt_U : 0.5700 - dt_P : 0.0022
#
#
# Accuracy on the validation data 0.76510066
#
# Epoch 9/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2491 - classify_zero_one: 0.7641 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 16.2192 - dt_U : 0.5700 - dt_P : 0.0022
#
#
# Accuracy on the validation data 0.7635215
#
# Epoch 10/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2491 - classify_zero_one: 0.7641 - ||W_U||_{infty} : 1.0000 - ||W_P||_{infty} : 16.2657 - dt_U : 0.5700 - dt_P : 0.0022
#
#
# Accuracy on the validation data 0.7627319
#
#
# End of training
#
# Saving validation data accuracy data
# [0.14567706, 0.8424793, 0.8085274, 0.78602445, 0.7781287, 0.7714173, 0.76786417, 0.7666798, 0.76510066, 0.7635215, 0.7627319]
# Maximal accuracy was 0.8424793
#
# Varying parameters time
#  88
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 49 	layers_K_shared : 4 	lr_U : 0.1 	lr_P : 0.01
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_49_4_2_1_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 3s 5ms/step - loss: 0.2449 - classify_zero_one: 0.6591 - ||W_U||_{infty} : 1.1681 - ||W_P||_{infty} : 6.1099 - dt_U : 0.4342 - dt_P : 0.0386
#
#
# Accuracy on the validation data 0.5341492
#
# Epoch 2/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2485 - classify_zero_one: 0.5366 - ||W_U||_{infty} : 1.5096 - ||W_P||_{infty} : 13.0872 - dt_U : 0.2563 - dt_P : 0.0035
#
#
# Accuracy on the validation data 0.5286222
#
# Epoch 3/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2491 - classify_zero_one: 0.5370 - ||W_U||_{infty} : 1.8844 - ||W_P||_{infty} : 17.1626 - dt_U : 0.1612 - dt_P : 0.0019
#
#
# Accuracy on the validation data 0.5317805
#
# Epoch 4/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2493 - classify_zero_one: 0.5393 - ||W_U||_{infty} : 2.0593 - ||W_P||_{infty} : 18.9064 - dt_U : 0.1345 - dt_P : 0.0016
#
#
# Accuracy on the validation data 0.53335965
#
# Epoch 5/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2493 - classify_zero_one: 0.5409 - ||W_U||_{infty} : 2.1468 - ||W_P||_{infty} : 19.7646 - dt_U : 0.1237 - dt_P : 0.0015
#
#
# Accuracy on the validation data 0.5349388
#
# Epoch 6/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2494 - classify_zero_one: 0.5425 - ||W_U||_{infty} : 2.1931 - ||W_P||_{infty} : 20.2110 - dt_U : 0.1185 - dt_P : 0.0014
#
#
# Accuracy on the validation data 0.53612316
#
# Epoch 7/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2494 - classify_zero_one: 0.5435 - ||W_U||_{infty} : 2.2221 - ||W_P||_{infty} : 20.4909 - dt_U : 0.1154 - dt_P : 0.0014
#
#
# Accuracy on the validation data 0.536518
#
# Epoch 8/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2494 - classify_zero_one: 0.5441 - ||W_U||_{infty} : 2.2374 - ||W_P||_{infty} : 20.6358 - dt_U : 0.1139 - dt_P : 0.0013
#
#
# Accuracy on the validation data 0.53691274
#
# Epoch 9/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2494 - classify_zero_one: 0.5442 - ||W_U||_{infty} : 2.2477 - ||W_P||_{infty} : 20.7340 - dt_U : 0.1128 - dt_P : 0.0013
#
#
# Accuracy on the validation data 0.53730756
#
# Epoch 10/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2494 - classify_zero_one: 0.5444 - ||W_U||_{infty} : 2.2532 - ||W_P||_{infty} : 20.7843 - dt_U : 0.1123 - dt_P : 0.0013
#
#
# Accuracy on the validation data 0.53730756
#
#
# End of training
#
# Saving validation data accuracy data
# [0.32570076, 0.5341492, 0.5286222, 0.5317805, 0.53335965, 0.5349388, 0.53612316, 0.536518, 0.53691274, 0.53730756, 0.53730756]
# Maximal accuracy was 0.53730756
#
# Varying parameters time
#  89
# eps : 0.0 	dt : 0.2 	ptt_cardnlty : 49 	layers_K_shared : 4 	lr_U : 0.1 	lr_P : 0.1
# Setting up a U layer with Neumann B.C.s.
# Setting up a subordinate model with phase
# Not saving best model
#
# filepath weights/0_0_49_4_2_2_fold_4
# Validation data available
# Epoch 1/10
# Training dt_U
# Training dt_P
# Training dt_U
# Training dt_P
# 317/317 [==============================] - 3s 5ms/step - loss: 0.2461 - classify_zero_one: 0.6862 - ||W_U||_{infty} : 3.9345 - ||W_P||_{infty} : 6.2252 - dt_U : 0.0832 - dt_P : 0.0354
#
#
# Accuracy on the validation data 0.7591788
#
# Epoch 2/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2483 - classify_zero_one: 0.7989 - ||W_U||_{infty} : 6.2208 - ||W_P||_{infty} : 9.7151 - dt_U : 0.0149 - dt_P : 0.0061
#
#
# Accuracy on the validation data 0.8231346
#
# Epoch 3/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2485 - classify_zero_one: 0.8341 - ||W_U||_{infty} : 7.1804 - ||W_P||_{infty} : 11.1573 - dt_U : 0.0111 - dt_P : 0.0046
#
#
# Accuracy on the validation data 0.8432689
#
# Epoch 4/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2486 - classify_zero_one: 0.8453 - ||W_U||_{infty} : 7.6802 - ||W_P||_{infty} : 11.9498 - dt_U : 0.0097 - dt_P : 0.0040
#
#
# Accuracy on the validation data 0.85313857
#
# Epoch 5/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2487 - classify_zero_one: 0.8521 - ||W_U||_{infty} : 7.9842 - ||W_P||_{infty} : 12.4224 - dt_U : 0.0089 - dt_P : 0.0037
#
#
# Accuracy on the validation data 0.8582708
#
# Epoch 6/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2487 - classify_zero_one: 0.8553 - ||W_U||_{infty} : 8.1478 - ||W_P||_{infty} : 12.6939 - dt_U : 0.0086 - dt_P : 0.0035
#
#
# Accuracy on the validation data 0.8606396
#
# Epoch 7/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2487 - classify_zero_one: 0.8570 - ||W_U||_{infty} : 8.2543 - ||W_P||_{infty} : 12.8689 - dt_U : 0.0084 - dt_P : 0.0034
#
#
# Accuracy on the validation data 0.8618239
#
# Epoch 8/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2487 - classify_zero_one: 0.8591 - ||W_U||_{infty} : 8.3205 - ||W_P||_{infty} : 12.9747 - dt_U : 0.0082 - dt_P : 0.0034
#
#
# Accuracy on the validation data 0.8618239
#
# Epoch 9/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2487 - classify_zero_one: 0.8593 - ||W_U||_{infty} : 8.3579 - ||W_P||_{infty} : 13.0370 - dt_U : 0.0082 - dt_P : 0.0034
#
#
# Accuracy on the validation data 0.8626135
#
# Epoch 10/10
# 317/317 [==============================] - 2s 5ms/step - loss: 0.2487 - classify_zero_one: 0.8599 - ||W_U||_{infty} : 8.3802 - ||W_P||_{infty} : 13.0750 - dt_U : 0.0081 - dt_P : 0.0033
#
#
# Accuracy on the validation data 0.86221874
#
#
# End of training
#
# Saving validation data accuracy data
# [0.20134228, 0.7591788, 0.8231346, 0.8432689, 0.85313857, 0.8582708, 0.8606396, 0.8618239, 0.8618239, 0.8626135, 0.86221874]
# Maximal accuracy was 0.8626135
#
#  It took 17246.567132234573 to run the model serially
# Creating Accuracies and parameter pickled file
# Statistics pickled to  Normal_all_grid_search_results0_1.p
